# %%
# !pip install dash
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/xinminaw/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install dash-trich-components
# Out:
# ...
#      |████████████████████████████████| 450 kB 5.2 MB/s eta 0:00:01
# ...
#   Created wheel for dash-trich-components: filename=dash_trich_components-1.0.0-py3-none-any.whl size=460324 sha256=89d78a2b3723265a0de4e86e2d7a1d34ddad54c7184a5c67e5b5fd4b893e03d3
#   Stored in directory: /Users/xinminaw/Library/Caches/pip/wheels/16/e2/12/f01e662c8b968d7d6829eb419826d3447019ce882d0998fab0
# Successfully built dash-trich-components
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/xinminaw/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install dash_bootstrap_components
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/xinminaw/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output, State
import pandas as pd
import plotly.express as px
import dash_trich_components as dtc
import dash_bootstrap_components as dbc
import dash_table
from collections import OrderedDict
from wordcloud import WordCloud, STOPWORDS
import base64
from io import BytesIO
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])
# Out:
# /Users/xinminaw/opt/anaconda3/lib/python3.8/site-packages/dash_bootstrap_components/_table.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# <ipython-input-4-bedaeaa96205>:9: UserWarning:
# The dash_table package is deprecated. Please replace
# `import dash_table` with `from dash import dash_table`
#
# Also, if you're using any of the table format helpers (e.g. Group), replace
# `from dash_table.Format import Group` with
# `from dash.dash_table.Format import Group`
#   import dash_table

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.PULSE])

# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "12rem",
    "padding": "2rem 1rem",
    "background-color": "#541D6E",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "14rem",
    #"margin-right": "2rem",
    #"padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.Img(src='https://creativereview.imgix.net/content/uploads/2016/10/NW_logo_still_800px.jpg', style={'height':'30%'}),
        #html.H2("Sidebar", className="display-4"),
        #html.Hr(),
        #html.P(
        #    "Exploring Portfolio Decarbonisation using AI", className="display-4"
        #),
        dbc.Nav(
            [
                dbc.NavLink("Dashboard", href="/", active="exact", style={'color':'#CBC3E3'}),
                dbc.NavLink("Insights", href="/insights", active="exact", style={'color':'#CBC3E3'}),
                dbc.NavLink("Upload", href="/upload", active="exact", style={'color':'#CBC3E3'}),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)

card = html.Div(
    [
        dtc.Card(
            image=app.get_asset_url ('PAGE5_IMAGE1_new.jpg'),
            title='Page 35',
            description='Table of Metrics',
            badges=['Carbon Footprint', 'GHG Emissions'],
            style={'display': 'inline-block', "padding": "0.3rem 0.3rem"}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE5_IMAGE1_new.jpg'),
            title='Page 5',
            description='Table of Metrics',
            badges=['Energy Consumption'],
            style={'display': 'inline-block', "padding": "0.3rem 0.3rem"}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE5_IMAGE1_new.jpg'),
            title='Page 23',
            description='Table of Metrics',
            badges=['Carbon Footprint', 'Scope 1', 'Scope 2'],
            style={'display': 'inline-block', "padding": "0.3rem 0.3rem"}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE35_IMAGE1.jpg'),
            title='Page 35',
            description='Table of Metrics',
            badges=['Carbon Footprint', 'GHG Emissions'],
            style={'display': 'inline-block', "padding": "0.3rem 0.3rem"}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE35_IMAGE1.jpg'),
            title='Page 35',
            description='Table of Metrics',
            badges=['Carbon Footprint', 'GHG Emissions'],
            style={"padding": "0.3rem 0.3rem", 'display': 'inline-block'}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE35_IMAGE1.jpg'),
            title='Page 35',
            description='Table of Metrics',
            badges=['Carbon Footprint', 'GHG Emissions'],
            style={"padding": "0.3rem 0.3rem", 'display': 'inline-block'}
        )
    ]
)

# create dataframe used for the figure later
df = pd.DataFrame({
"Decarbonisation Category": ["Emissions", "Renewables", "Waste", "Sustainable Investing", "Others"],
"Sentiment Score": [0.65, 1, 0.8, 0.9, 0.92],
})

barchart_sentiment = px.bar(df, x="Decarbonisation Category", y="Sentiment Score")

# data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/solar.csv')
data = OrderedDict(
    [
        ("No.", [1, 2, 3]),
        (
            "Sentence",
            [
                "At the end of 2019, we had reduced our GHG emissions by 71% compared to baseline year 2004.",
                "These efforts reduced energy consumption by more than 2,100 metric tons (mt) of carbon dioxide equivalents (CO2e) during the one-year challenge.",
                "For public and private assets, excluding cash and non-equity derivatives as they were not reported in 2019, our year-over-year portfolio weighted average carbon intensity was reduced by approximately 23%.",
            ],
        ),
        ("Relevance (%)", [97, 67, 83]),
        (
            "Category",
            ["Carbon", "Sustainable Investing", "Energy"],
        ),
    ]
)

df2 = pd.DataFrame(data)

CHARTS_STYLE = {
    #"float": "right",
    "width": "23rem",
    "padding": "1.5rem 1rem",
    "height": "150vh",
    "background-color": "#E0E0E0",
    "position":"absolute",
    "top": 0,
    "right": 0
}

TABLE_STYLE = {
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "65%",
    "padding": "2rem 1rem",
    'display': 'inline-block'
}

BARCHART_STYLE = {
    #"top": 0,
    #"left": 0,
    #"bottom": 0,
    #"width": "40%",
    'vertical-align': 'top',
    'display': 'inline-block'
}

WORDCLOUD_STYLE = {
    #"top": 0,
    #"left": 0,
    #"bottom": 0,
    #"width": "40%",
    'vertical-align': 'top',
    'display': 'inline-block',
    'padding-left': '3rem', 
    'padding-top': '2rem'
}


dashboard = html.Div([
    html.Div([
    html.H4("Company: DBS", style={'padding-right': '3rem', 'padding-top': '1.5rem', 'display': 'inline-block'}),
    html.H4("Year: 2020", style={'padding-top': '1.5rem', 'display': 'inline-block'})
    ]),
    html.Div(
                [dcc.Graph(style={'width': '45vh', 'height': '60vh'},    figure={
        'data': [
            {'x': ["Emissions", "Renewables", "Waste", "Sustainable Investing", "Others"], 'y': [0.65, 1, 0.8, 0.9, 0.92], 
             'type': 'bar', 'name': 'Category'},
        ],
        'layout': {
            'title': 'Average Sentiment Score',
            'margin': {'r':70,'l':10}
            #"height": 100, 
        }
    })],
               style=BARCHART_STYLE
            ),
    html.Div([
        html.H6("Word Cloud of Top 10 Keywords in Each Topic"),
        html.Img(src=app.get_asset_url('wordcloud.png'), style={'width': '60vh', 'height': '50vh'})
    ], style = WORDCLOUD_STYLE),
    html.Div([
        html.H5("Decarbonisation-Related Information"),
        dash_table.DataTable(
            columns=[{"name": i, "id": i} for i in df2.columns],
            style_data={
                #'overflowX': 'auto',
                'whiteSpace': 'normal',
                'height': 'auto',
            },
            style_header={
                'backgroundColor': '#D71C2B',
                'color': 'white'
            },
            data=df2.to_dict('records'))
    ], style = TABLE_STYLE),
    html.Div([
        html.H4("Relevant Metrics"),
        dtc.Card(
            image=app.get_asset_url ('CHART.jpg'),
            title='Page 5',
            #description='Table of Metrics',
            badges=['ESG Ratings', 'GHG Emissions'],
            style={"padding": "0.3rem 0.3rem"}
        ),
        dtc.Card(
            image=app.get_asset_url ('PAGE35_IMAGE1.jpg'),
            title='Page 35',
            #description='Table of Metrics',
            badges=['Energy Consumption'],
            style={"padding": "0.3rem 0.3rem"}
        ),
    ], style = CHARTS_STYLE)
])

upload_fn = html.Div([
    html.Div([
    html.H4("Upload a PDF file"),
    dcc.Upload([
        'Drag and Drop or ',
        html.A('Select a File')
    ], style={
        'width': '93%',
        'height': '60px',
        'lineHeight': '60px',
        'borderWidth': '1px',
        'borderStyle': 'dashed',
        'borderRadius': '5px',
        'textAlign': 'center'
    })
    ], style={'padding-bottom':'2rem'}),
    html.H4("OR", style={'textAlign': 'center', 'padding-bottom':'2rem'}),
    html.Div([
    html.H4("Enter URL of PDF report:"),
    dcc.Input(
        type='text',
        placeholder="Enter URL here", size='100',
    ),
        html.Div([
    html.H5("Enter Company Name:"),
    dcc.Input(
        type='text',
        placeholder="Enter company name here", size='45',
    )], style={'padding-top':'2rem', 'padding-right':'1.8rem', 'display': 'inline-block'}),
            html.Div([
    html.H5("Enter Year of Report:"),
    dcc.Input(
        type='text',
        placeholder="Enter year here", size='45',
    )], style={'padding-top':'2rem', 'display': 'inline-block'})
    ], style={'width': '100%', 'display': 'inline-block'}),
], style = {#'position': 'absolute',
        #'top': '40%',
        #'left': '30%',
        'padding-left':'13%', 
        'padding-top':'10%', 
        'padding-right':'15%'
        #'display': 'inline-block'
        #'margin-right': '-30%',
        #'transform': 'translate(-50%, -50%)'
           })
    
content = html.Div(id="page-content", style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar, content])

@app.callback(Output("page-content", "children"), [Input("url", "pathname")])
def render_page_content(pathname):
    if pathname == "/":
        #return html.P("This is the content of the home page!")
        return dashboard
    elif pathname == "/insights":
        return card
    elif pathname == "/upload":
        return upload_fn
    # If the user tries to reach a different page, return a 404 message
    return dbc.Jumbotron(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ]
    )


if __name__ == "__main__":
    app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %% [markdown]
# ## END

# %%
card = dtc.Card(
            link='https://linkhere.com',
            image='image_path_here',
            title='Title text',
            description='Description text',
            badges=['Badge 1', 'Badge 2', 'Badge 3'],
            git='https://githublinkhere.com',
            dark=True
        )

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

app.layout = html.Div([
    dcc.Upload(
        id='upload-image',
        children=html.Div([
            'Drag and Drop or ',
            html.A('Select Files')
        ]),
        style={
            'width': '100%',
            'height': '60px',
            'lineHeight': '60px',
            'borderWidth': '1px',
            'borderStyle': 'dashed',
            'borderRadius': '5px',
            'textAlign': 'center',
            'margin': '10px'
        },
        # Allow multiple files to be uploaded
        multiple=True
    ),
    html.Div(id='output-image-upload'),
])

def parse_contents(contents, filename, date):
    return html.Div([
        html.H5(filename),
        html.H6(datetime.datetime.fromtimestamp(date)),

        # HTML images accept base64 encoded strings in the same format
        # that is supplied by the upload
        html.Img(src=contents),
        html.Hr(),
        html.Div('Raw Content'),
        html.Pre(contents[0:200] + '...', style={
            'whiteSpace': 'pre-wrap',
            'wordBreak': 'break-all'
        })
    ])

@app.callback(Output('output-image-upload', 'children'),
              Input('upload-image', 'contents'),
              State('upload-image', 'filename'),
              State('upload-image', 'last_modified'))
def update_output(list_of_contents, list_of_names, list_of_dates):
    if list_of_contents is not None:
        children = [
            parse_contents(c, n, d) for c, n, d in
            zip(list_of_contents, list_of_names, list_of_dates)]
        return children

if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)

# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html

# create your dash app
app = dash.Dash(__name__)

# add different color styles
colors = {
    'background': 'pink',
    'plot-background':'brown',
    'text': 'blue'
}

df = pd.DataFrame({
    "Occupation": ["Teacher", "Banker", "Engineer", "Teacher", "Banker", "Engineer"],
    "Number of employees": [40, 45, 35, 20, 24, 50],
    "Gender": ["F", "F", "F", "M", "M", "M"]
})

# plotly figure
fig = px.bar(df, x="Occupation", y="Number of employees", color="Gender", barmode="group")

# customize figure background color as yellow and font color as blue in the figure
fig.update_layout(
    plot_bgcolor=colors['plot-background'],
    font_color=colors['text']
)

# app layout
app.layout = html.Div(style={'backgroundColor': colors['background']},children=[
    html.H1(children='BT3103 Dash', style={'textAlign':'center'}),
    html.Div(children='Dash: A web application framework for Python.', 
            style={'color':colors['text'], 'textAlign':'center', 'margin-bottom':'20px'}),
    dcc.Graph(
        id='example2',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
